# %%
#Import libraries
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("./titanic/train.csv")
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
for f in train_data.columns:
    print(f, train_data[f].isnull().sum())
# Out:
# PassengerId 0
# Survived 0
# Pclass 0
# Name 0
# Sex 0
# Age 177
# SibSp 0
# Parch 0
# Ticket 0
# Fare 0
# Cabin 687
# Embarked 2

# %%
total_women = train_data.loc[train_data.Sex == "female"]

# %%
total_women["Survived"]
# Out:
# 1      1
# 2      1
# 3      1
# 8      1
# 9      1
#       ..
# 880    1
# 882    0
# 885    0
# 887    1
# 888    0
# Name: Survived, Length: 314, dtype: int64

# %%
len(total_women)
# Out:
# 314

# %%
sum(total_women["Survived"])
# Out:
# 233

# %%
rate_women_survived = sum(total_women["Survived"])/len(total_women)

# %%
rate_women_survived
# Out:
# 0.7420382165605095

# %%
men = train_data.loc[train_data.Sex == 'male']["Survived"]

# %%
rate_men_survived = sum(men)/len(men)

# %%
rate_men_survived
# Out:
# 0.18890814558058924

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Y = train_data["Survived"]

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
features = ["Pclass", "Sex", "SibSp", "Parch"]

# %%
test_data = pd.read_csv("./titanic/test.csv")
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

# %%
X.head()
# Out:
#    Pclass  SibSp  Parch  Sex_female  Sex_male
# 0       3      1      0       False      True
# 1       1      1      0        True     False
# 2       3      0      0        True     False
# 3       1      1      0        True     False
# 4       3      0      0       False      True

# %%
X_test.head()
# Out:
#    Pclass  SibSp  Parch  Sex_female  Sex_male
# 0       3      0      0       False      True
# 1       3      1      0        True     False
# 2       2      0      0       False      True
# 3       3      0      0       False      True
# 4       3      1      1        True     False

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pclass      891 non-null    int64
#  1   SibSp       891 non-null    int64
#  2   Parch       891 non-null    int64
#  3   Sex_female  891 non-null    bool
#  4   Sex_male    891 non-null    bool
# dtypes: bool(2), int64(3)
# memory usage: 22.8 KB

# %%
train_data[features]
# Out:
#      Pclass     Sex  SibSp  Parch
# 0         3    male      1      0
# 1         1  female      1      0
# 2         3  female      0      0
# 3         1  female      1      0
# 4         3    male      0      0
# ..      ...     ...    ...    ...
# 886       2    male      0      0
# 887       1  female      0      0
# 888       3  female      1      2
# 889       1    male      0      0
# 890       3    male      0      0
#
# [891 rows x 4 columns]

# %%
train_data[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    object
#  2   SibSp   891 non-null    int64
#  3   Parch   891 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 28.0+ KB

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#n_estimators=100 is 100 trees
#max_depth=5 limits each tree to depth 5

"""
# Without random_state - different results each time
model1 = RandomForestClassifier(n_estimators=100, max_depth=5)
model1.fit(X, Y)
accuracy1 = model1.score(X, Y)  # Might be 0.823

model2 = RandomForestClassifier(n_estimators=100, max_depth=5)  
model2.fit(X, Y)
accuracy2 = model2.score(X, Y)  # Might be 0.831 (different!)

# With random_state - same results each time
model1 = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model2 = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
# Both will give identical results

"""
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)

# %%
model.fit(X, Y)
# Out:
# RandomForestClassifier(max_depth=5, random_state=1)

# %%
#Test the model over the test data
predictions = model.predict(X_test)

# %%
output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
